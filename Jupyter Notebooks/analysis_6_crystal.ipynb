# %%
from pyiron import Project
from pyiron import ase_to_pyiron, pyiron_to_ase
import sys  
sys.path.insert(0, '/nfshome/deshmukh/vaibhav/scripts')
import analysis_msd as ms

# %% [markdown]
# li = [523,573,623,673,723,773]
# for i in li:
#     ms.ovito_msd.diff_2(path_line='/nfshome/deshmukh/pyiron/projects/NASICON/project/hena/hena_2_2/minimization/hena_2_2/hena_1_struct_eq_big_%sk_6/dump_nvt_prod.out'%i,file_2='msd_na_big_%sk_6.txt'%i,step=2.00, dump_write=200, step_ovito=1)

# %%
d,x,y = ms.msd.dff_coefficient(file='msd_na_big_523k_6.txt',dim=3,temp=523,save=False,file_2="avg_msd_773k_5.png",y_val=12)
d_1,x_1,y_1 = ms.msd.dff_coefficient(file='msd_na_big_573k_6.txt',dim=3,temp=573,save=False,file_2="avg_msd_773k_5.png",y_val=12)
d_2,x_2,y_2 = ms.msd.dff_coefficient(file='msd_na_big_623k_6.txt',dim=3,temp=623,save=False,file_2="avg_msd_773k_5.png",y_val=12)
d_3,x_3,y_3 = ms.msd.dff_coefficient(file='msd_na_big_673k_6.txt',dim=3,temp=673,save=False,file_2="avg_msd_773k_5.png",y_val=12)
d_4,x_4,y_4 = ms.msd.dff_coefficient(file='msd_na_big_723k_6.txt',dim=3,temp=723,save=False,file_2="avg_msd_773k_5.png",y_val=12)
d_5,x_5,y_5 = ms.msd.dff_coefficient(file='msd_na_big_773k_6.txt',dim=3,temp=773,save=True,file_2="avg_msd_crystal_6.png",y_val=12)
# Out:
# Diffusion coefficient = 1.904e-11 [M^2/sec]
# Diffusion coefficient = 3.674e-11 [M^2/sec]
# Diffusion coefficient = 5.545e-11 [M^2/sec]
# Diffusion coefficient = 8.861e-11 [M^2/sec]
# Diffusion coefficient = 1.300e-10 [M^2/sec]
# Diffusion coefficient = 1.930e-10 [M^2/sec]

# %%
ms.msd.get_arrhenius_plot(temps=[523,573,623,673,723,773],diffusivities=[1.904e-11,3.674e-11,5.545e-11,8.861e-11,1.300e-10,1.930e-10],save=True,file='activation_energy_cryst_latest_6.png')

# %%
ms.msd.get_extrapolated_diffusivity(temps=[523,573,623,673,723,773],diffusivities=[1.904e-11,3.674e-11,5.545e-11,8.861e-11,1.300e-10,1.930e-10],new_temp=303)
# Out:
# 1.1564319906595022e-13

# %%
d,x,y = ms.msd.dff_coefficient(file='msd_na_big_glass_523k_6.txt',dim=3,temp=523,save=False,file_2="avg_msd_773k_5.png",y_val=12)
d_1,x_1,y_1 = ms.msd.dff_coefficient(file='msd_na_big_glass_573k_6.txt',dim=3,temp=573,save=False,file_2="avg_msd_773k_5.png",y_val=12)
d_2,x_2,y_2 = ms.msd.dff_coefficient(file='msd_na_big_glass_623k_6.txt',dim=3,temp=623,save=False,file_2="avg_msd_773k_5.png",y_val=12)
d_3,x_3,y_3 = ms.msd.dff_coefficient(file='msd_na_big_glass_673k_6.txt',dim=3,temp=673,save=False,file_2="avg_msd_773k_5.png",y_val=12)
d_4,x_4,y_4 = ms.msd.dff_coefficient(file='msd_na_big_glass_723k_6.txt',dim=3,temp=723,save=False,file_2="avg_msd_773k_5.png",y_val=12)
d_5,x_5,y_5 = ms.msd.dff_coefficient(file='msd_na_big_glass_773k_6.txt',dim=3,temp=773,save=True,file_2="avg_msd_glass_6.png",y_val=12)
# Out:
# Diffusion coefficient = 4.938e-12 [M^2/sec]
# Diffusion coefficient = 7.951e-12 [M^2/sec]
# Diffusion coefficient = 1.319e-11 [M^2/sec]
# Diffusion coefficient = 2.258e-11 [M^2/sec]
# Diffusion coefficient = 3.375e-11 [M^2/sec]
# Diffusion coefficient = 5.044e-11 [M^2/sec]

# %%
ms.msd.get_arrhenius_plot(temps=[523,573,623,673,723,773],diffusivities=[4.938e-12,7.951e-12,1.319e-11,2.258e-11,3.375e-11,5.044e-11],save=True,file='activation_energy_glass_latest.png')

# %%
ms.msd.get_extrapolated_diffusivity(temps=[523,573,623,673,723,773],diffusivities=[4.938e-12,7.951e-12,1.319e-11,2.258e-11,3.375e-11,5.044e-11],new_temp=303)
# Out:
# 2.2786311152068532e-14

# %%
import numpy as np
# Plot the arrehnious plot together 
df_tot_cr = [1.904e-11,3.674e-11,5.545e-11,8.861e-11,1.300e-10,1.930e-10]
df_tot_cr_e = [4.938e-12,7.951e-12,1.319e-11,2.258e-11,3.375e-11,5.044e-11]

# %%
import scipy.constants as const
import sys  
sys.path.insert(0, '/nfshome/deshmukh/vaibhav/scripts')
import analysis_msd as ms

temp = [523,573,623,673,723,773]

# %%
# x
#Ea, c, _ = ms.msd.fit_arrhenius(temp, df_x_cr)                        # Activation energy 
#arr = (c * np.exp(-Ea / (const.k / const.e * np.array(temp))))*0.0001   # get log of diffusion
# y
#Ea_1, c_1, _1 = ms.msd.fit_arrhenius(temp, df_y_cr)                      # Activation energy 
#arr_1 = (c_1 * np.exp(-Ea_1 / (const.k / const.e * np.array(temp))))*0.0001   # get log of diffusion
# z
#Ea_2, c_2, _2 = ms.msd.fit_arrhenius(temp, df_z_cr)                        # Activation energy 
#arr_2 = (c_2 * np.exp(-Ea_2 / (const.k / const.e * np.array(temp))))*0.0001   # get log of diffusion
# tot
Ea_3, c_3, _3 = ms.msd.fit_arrhenius(temp, df_tot_cr)                      # Activation energy 
arr_3 = (c_3 * np.exp(-Ea_3 / (const.k / const.e * np.array(temp))))*0.0001   # get log of diffusion

# x
#Ea_e, c_e, _e = ms.msd.fit_arrhenius(temp, df_x_cr_e)                        # Activation energy 
#arr_e = (c_e * np.exp(-Ea_e / (const.k / const.e * np.array(temp))))*0.0001   # get log of diffusion
## y
#Ea_1_e, c_1_e, _1_e = ms.msd.fit_arrhenius(temp, df_y_cr_e)                      # Activation energy 
#arr_1_e = (c_1_e * np.exp(-Ea_1_e / (const.k / const.e * np.array(temp))))*0.0001   # get log of diffusion
## z
#Ea_2_e, c_2_e, _2_e = ms.msd.fit_arrhenius(temp, df_z_cr_e)                        # Activation energy 
#arr_2_e = (c_2_e * np.exp(-Ea_2_e / (const.k / const.e * np.array(temp))))*0.0001   # get log of diffusion
## tot
Ea_3_e, c_3_e, _3_e = ms.msd.fit_arrhenius(temp, df_tot_cr_e)                      # Activation energy 
arr_3_e = (c_3_e * np.exp(-Ea_3_e / (const.k / const.e * np.array(temp))))*0.0001   # get log of diffusion

# %%
t_1 = 1000 / np.array(temp)           # temperature
plusminus = u"\u00B1"

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.autolayout"] = True
plt.rcParams["figure.facecolor"] = "w"
plt.rcParams["figure.figsize"] = (7,7)
plt.rcParams.update({'font.size': 14})
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
#plt.xlim([0, 10])
#plt.ylim([10e-12, 10e-8])
plt.tick_params(bottom=True, top=True, left=True, right=True)
plt.rcParams["axes.linewidth"] = 3
plt.rcParams["patch.linewidth"] = 3
plt.tick_params(which='both', axis="y",direction="in")
plt.tick_params(which='both', axis="x",direction="in")
plt.tick_params(width=3, length=4.5)

#plt.errorbar(t_1,arr,yerr=std_arr,linestyle='--',fmt = 'o',markersize='8',color = 'royalblue', ecolor = 'royalblue',elinewidth = 2, capsize=5,label='$E_{a}^{x}$' + '= {:0.3f} {} {:0.3f} eV'.format(Ea,f'{plusminus}',_), linewidth=3, alpha=0.75)
#plt.errorbar(t_1,arr_1,yerr=std_arr_1,linestyle='--',fmt = '<',markersize='8',color = 'darkorange', ecolor = 'darkorange', elinewidth = 2, capsize=5,label='$E_{a}^{y}$'+ ' = {:0.3f} {} {:0.3f} eV'.format(Ea_1,f'{plusminus}',_1), linewidth=3, alpha=0.75)
#plt.errorbar(t_1,arr_2,yerr=std_arr_2,linestyle='--',fmt = '>',markersize='8',color = 'green', ecolor = 'green',elinewidth = 2, capsize=5,label='$E_{a}^{z}$' + '= {:0.3f} {} {:0.3f} eV'.format(Ea_2,f'{plusminus}',_2), linewidth=3, alpha=0.75)
plt.errorbar(t_1,arr_3,linestyle='--',fmt = 's',markersize='8',color = 'blue', ecolor = 'blue', elinewidth = 2, capsize=5,label='$E_{cr}^{tot}$'+ ' = {:0.3f} {} {:0.3f} eV'.format(Ea_3,f'{plusminus}',_3), linewidth=3, alpha=0.75)
plt.errorbar(t_1,arr_3_e,linestyle='--',fmt = 's',markersize='8',color = 'red', ecolor = 'red', elinewidth = 2, capsize=5,label='$E_{am}^{tot}$'+ ' = {:0.3f} {} {:0.3f} eV'.format(Ea_3_e,f'{plusminus}',_3_e), linewidth=3, alpha=0.75)

plt.yscale("log")
#plt.title("Arrhenius Plot Crystal vs Amorphous (Ordered)")
plt.xlabel("1000/$Temperature \ (1/K)$", fontsize=16)
plt.ylabel("$log(D_{Tr}\ (m^2/Sec))$", fontsize=16)
plt.legend(fancybox=False, framealpha=1, shadow=False, borderpad=0.5, frameon=True, edgecolor="black", loc='upper right')#,fontsize=11,ncol=2)#, bbox_to_anchor=(1.60, 1.019))
twin_axes=plt.twiny() 
twin_axes.set_xlim((1/t_1[5])*1000, (1/t_1[0])*1000)
twin_axes.set_xlabel("$Temperature \ (K)$",fontsize=16)
twin_axes.tick_params(axis="x", direction="in")
twin_axes.tick_params(width=3, length=4.5)
plt.savefig('crystalline_activation_energy_hena_2.png', bbox_inches='tight', dpi=600, transparent=False)
plt.show()
