# %%
from pyiron import Project, ase_to_pyiron
import matplotlib.pyplot as plt
import numpy as np
from pyiron import Project
from ase.io import read, write
from pyiron import ase_to_pyiron
import ase
import os
import time
import lammps_logfile

# %%
# All glass compositions 
g_3_1_3 = lammps_logfile.File('/nfshome/deshmukh/vaibhav/frank_jÜlich/lmp_3_1_3/large/simu/log.lammps')
g_3_2_3 = lammps_logfile.File('/nfshome/deshmukh/vaibhav/frank_jÜlich/lmp_3_2_3/large/simu/log.lammps')
g_5_2_2 = lammps_logfile.File('/nfshome/deshmukh/vaibhav/frank_jÜlich/lmp_5_2_2/large/simu/log.lammps')
g_6_1_6 = lammps_logfile.File('/nfshome/deshmukh/vaibhav/frank_jÜlich/lmp_6_1_6/large/simu/log.lammps')
g_6_1_3 = lammps_logfile.File('/nfshome/deshmukh/vaibhav/frank_jÜlich/lmp_6_1_3_2/simu_2/log.lammps')

# %%
print(g_3_1_3.get_num_partial_logs(), g_3_2_3.get_num_partial_logs(), g_5_2_2.get_num_partial_logs(), g_6_1_6.get_num_partial_logs(), g_6_1_3.get_num_partial_logs())
# Out:
# 7 7 7 7 7

# %%
# Density and volume of all glass compositions
g_1_d = g_3_1_3.get('Density', run_num=4)
g_1_v = g_3_1_3.get('Volume', run_num=4)
g_1_t = g_3_1_3.get('Temp', run_num=6)
g_1_x = g_3_1_3.get('Lx', run_num=4)
g_1_y = g_3_1_3.get('Ly', run_num=4)
g_1_z = g_3_1_3.get('Lz', run_num=4)
g_1_pe = g_3_1_3.get('PotEng', run_num=6)
g_1_tot = g_3_1_3.get('TotEng', run_num=6)

g_2_d = g_3_2_3.get('Density', run_num=4)
g_2_v = g_3_2_3.get('Volume', run_num=4)
g_2_t = g_3_2_3.get('Temp', run_num=6)
g_2_x = g_3_2_3.get('Lx', run_num=4)
g_2_y = g_3_2_3.get('Ly', run_num=4)
g_2_z = g_3_2_3.get('Lz', run_num=4)
g_2_pe = g_3_2_3.get('PotEng', run_num=6)
g_2_tot = g_3_2_3.get('TotEng', run_num=6)

g_3_d = g_5_2_2.get('Density', run_num=4)
g_3_v = g_5_2_2.get('Volume', run_num=4)
g_3_t = g_5_2_2.get('Temp', run_num=6)
g_3_x = g_5_2_2.get('Lx', run_num=4)
g_3_y = g_5_2_2.get('Ly', run_num=4)
g_3_z = g_5_2_2.get('Lz', run_num=4)
g_3_pe = g_5_2_2.get('PotEng', run_num=6)
g_3_tot = g_5_2_2.get('TotEng', run_num=6)

g_4_d = g_6_1_6.get('Density', run_num=4)
g_4_v = g_6_1_6.get('Volume', run_num=4)
g_4_t = g_6_1_6.get('Temp', run_num=6)
g_4_x = g_6_1_6.get('Lx', run_num=4)
g_4_y = g_6_1_6.get('Ly', run_num=4)
g_4_z = g_6_1_6.get('Lz', run_num=4)
g_4_pe = g_6_1_6.get('PotEng', run_num=6)
g_4_tot = g_6_1_6.get('TotEng', run_num=6)

g_5_d = g_6_1_3.get('Density', run_num=4)
g_5_v = g_6_1_3.get('Volume', run_num=4)
g_5_t = g_6_1_3.get('Temp', run_num=6)
g_5_x = g_6_1_3.get('Lx', run_num=4)
g_5_y = g_6_1_3.get('Ly', run_num=4)
g_5_z = g_6_1_3.get('Lz', run_num=4)
g_5_pe = g_6_1_3.get('PotEng', run_num=6)
g_5_tot = g_6_1_3.get('TotEng', run_num=6)

# %%
# Plotting density 
plt.plot(g_1_d, label='3_1_3')
plt.plot(g_2_d, label='3_2_3')
plt.plot(g_3_d, label='5_2_2')
plt.plot(g_4_d, label='6_1_6')
plt.plot(g_5_d, label='6_1_3')
plt.legend()
plt.xlabel('Time (fs)')
plt.ylabel('Density (g/cm^3)')
plt.title('Density vs Time')
plt.show()
# Print average density with standard deviation, the float values are not more than three decimal places
print('Average density of 3_1_3 is', np.round(np.mean(g_1_d),3),'(g/cm³)', 'with standard deviation', np.round(np.std(g_1_d),3),'(g/cm³)')
print('Average density of 3_2_3 is', np.round(np.mean(g_2_d),3),'(g/cm³)', 'with standard deviation', np.round(np.std(g_2_d),3),'(g/cm³)')
print('Average density of 5_2_2 is', np.round(np.mean(g_3_d),3),'(g/cm³)', 'with standard deviation', np.round(np.std(g_3_d),3),'(g/cm³)')
print('Average density of 6_1_6 is', np.round(np.mean(g_4_d),3),'(g/cm³)', 'with standard deviation', np.round(np.std(g_4_d),3),'(g/cm³)')
print('Average density of 6_1_3 is', np.round(np.mean(g_5_d),3),'(g/cm³)', 'with standard deviation', np.round(np.std(g_5_d),3),'(g/cm³)')
# Out:
# Average density of 3_1_3 is 2.573 (g/cm³) with standard deviation 0.007 (g/cm³)
# Average density of 3_2_3 is 2.587 (g/cm³) with standard deviation 0.006 (g/cm³)
# Average density of 5_2_2 is 2.587 (g/cm³) with standard deviation 0.006 (g/cm³)
# Average density of 6_1_6 is 2.45 (g/cm³) with standard deviation 0.005 (g/cm³)
# Average density of 6_1_3 is 2.643 (g/cm³) with standard deviation 0.006 (g/cm³)

# %%
# Plotting volume
plt.plot(g_1_v, label='3_1_3')
plt.plot(g_2_v, label='3_2_3')
plt.plot(g_3_v, label='5_2_2')
plt.plot(g_4_v, label='6_1_6')
plt.plot(g_5_v, label='6_1_3')
plt.legend()
plt.xlabel('Time (fs)')
plt.ylabel('Volume (Å³)')
plt.title('Volume vs Time')
plt.show()
# Print average volume with standard deviation, the float values are not more than three decimal places
print('Average volume of 3_1_3 is', np.round(np.mean(g_1_v),3),'(Å³)', 'with standard deviation', np.round(np.std(g_1_v),3),'(Å³)')
print('Average volume of 3_2_3 is', np.round(np.mean(g_2_v),3),'(Å³)', 'with standard deviation', np.round(np.std(g_2_v),3),'(Å³)')
print('Average volume of 5_2_2 is', np.round(np.mean(g_3_v),3),'(Å³)', 'with standard deviation', np.round(np.std(g_3_v),3),'(Å³)')
print('Average volume of 6_1_6 is', np.round(np.mean(g_4_v),3),'(Å³)', 'with standard deviation', np.round(np.std(g_4_v),3),'(Å³)')
print('Average volume of 6_1_3 is', np.round(np.mean(g_5_v),3),'(Å³)', 'with standard deviation', np.round(np.std(g_5_v),3),'(Å³)')
# Out:
# Average volume of 3_1_3 is 17710.861 (Å³) with standard deviation 47.479 (Å³)
# Average volume of 3_2_3 is 22253.619 (Å³) with standard deviation 55.021 (Å³)
# Average volume of 5_2_2 is 24750.619 (Å³) with standard deviation 59.795 (Å³)
# Average volume of 6_1_6 is 30262.501 (Å³) with standard deviation 67.782 (Å³)
# Average volume of 6_1_3 is 23546.398 (Å³) with standard deviation 55.219 (Å³)

# %%
# Plotting temperature
plt.plot(g_1_t, label='3_1_3')
plt.plot(g_2_t, label='3_2_3')
plt.plot(g_3_t, label='5_2_2')
plt.plot(g_4_t, label='6_1_6')
plt.plot(g_5_t, label='6_1_3')
plt.legend()
plt.xlabel('Time (fs)')
plt.ylabel('Temperature (K)')
plt.title('Temperature vs Time')
plt.show()
# Print average temperature with standard deviation, the float values are not more than three decimal places
print('Average temperature of 3_1_3 is', np.round(np.mean(g_1_t),3),'(K)', 'with standard deviation', np.round(np.std(g_1_t),3),'(K)')
print('Average temperature of 3_2_3 is', np.round(np.mean(g_2_t),3),'(K)', 'with standard deviation', np.round(np.std(g_2_t),3),'(K)')
print('Average temperature of 5_2_2 is', np.round(np.mean(g_3_t),3),'(K)', 'with standard deviation', np.round(np.std(g_3_t),3),'(K)')
print('Average temperature of 6_1_6 is', np.round(np.mean(g_4_t),3),'(K)', 'with standard deviation', np.round(np.std(g_4_t),3),'(K)')
print('Average temperature of 6_1_3 is', np.round(np.mean(g_5_t),3),'(K)', 'with standard deviation', np.round(np.std(g_5_t),3),'(K)')
# Out:
# Average temperature of 3_1_3 is 301.02 (K) with standard deviation 6.191 (K)
# Average temperature of 3_2_3 is 299.951 (K) with standard deviation 5.968 (K)
# Average temperature of 5_2_2 is 300.35 (K) with standard deviation 5.499 (K)
# Average temperature of 6_1_6 is 300.038 (K) with standard deviation 5.064 (K)
# Average temperature of 6_1_3 is 299.479 (K) with standard deviation 5.297 (K)

# %%
# Plotting Lx
plt.plot(g_1_x, label='3_1_3')
plt.plot(g_2_x, label='3_2_3')
plt.plot(g_3_x, label='5_2_2')
plt.plot(g_4_x, label='6_1_6')
plt.plot(g_5_x, label='6_1_3')
plt.legend()
plt.xlabel('Time (fs)')
plt.ylabel('Lx (Å)')
plt.title('Lx vs Time')
plt.show()
# Print average Lx with standard deviation, the float values are not more than three decimal places
print('Average Lx of 3_1_3 is', np.round(np.mean(g_1_x),3),'(Å)', 'with standard deviation', np.round(np.std(g_1_x),3),'(Å)')
print('Average Lx of 3_2_3 is', np.round(np.mean(g_2_x),3),'(Å)', 'with standard deviation', np.round(np.std(g_2_x),3),'(Å)')
print('Average Lx of 5_2_2 is', np.round(np.mean(g_3_x),3),'(Å)', 'with standard deviation', np.round(np.std(g_3_x),3),'(Å)')
print('Average Lx of 6_1_6 is', np.round(np.mean(g_4_x),3),'(Å)', 'with standard deviation', np.round(np.std(g_4_x),3),'(Å)')
print('Average Lx of 6_1_3 is', np.round(np.mean(g_5_x),3),'(Å)', 'with standard deviation', np.round(np.std(g_5_x),3),'(Å)')
# Out:
# Average Lx of 3_1_3 is 26.066 (Å) with standard deviation 0.023 (Å)
# Average Lx of 3_2_3 is 28.128 (Å) with standard deviation 0.023 (Å)
# Average Lx of 5_2_2 is 29.143 (Å) with standard deviation 0.023 (Å)
# Average Lx of 6_1_6 is 31.163 (Å) with standard deviation 0.023 (Å)
# Average Lx of 6_1_3 is 28.662 (Å) with standard deviation 0.022 (Å)

# %%
# Plotting Ly
plt.plot(g_1_y, label='3_1_3')
plt.plot(g_2_y, label='3_2_3')
plt.plot(g_3_y, label='5_2_2')
plt.plot(g_4_y, label='6_1_6')
plt.plot(g_5_y, label='6_1_3')
plt.legend()
plt.xlabel('Time (fs)')
plt.ylabel('Ly (Å)')
plt.title('Ly vs Time')
plt.show()
# Print average Ly with standard deviation, the float values are not more than three decimal places
print('Average Ly of 3_1_3 is', np.round(np.mean(g_1_y),3),'(Å)', 'with standard deviation', np.round(np.std(g_1_y),3),'(Å)')
print('Average Ly of 3_2_3 is', np.round(np.mean(g_2_y),3),'(Å)', 'with standard deviation', np.round(np.std(g_2_y),3),'(Å)')
print('Average Ly of 5_2_2 is', np.round(np.mean(g_3_y),3),'(Å)', 'with standard deviation', np.round(np.std(g_3_y),3),'(Å)')
print('Average Ly of 6_1_6 is', np.round(np.mean(g_4_y),3),'(Å)', 'with standard deviation', np.round(np.std(g_4_y),3),'(Å)')
print('Average Ly of 6_1_3 is', np.round(np.mean(g_5_y),3),'(Å)', 'with standard deviation', np.round(np.std(g_5_y),3),'(Å)')
# Out:
# Average Ly of 3_1_3 is 26.066 (Å) with standard deviation 0.023 (Å)
# Average Ly of 3_2_3 is 28.128 (Å) with standard deviation 0.023 (Å)
# Average Ly of 5_2_2 is 29.143 (Å) with standard deviation 0.023 (Å)
# Average Ly of 6_1_6 is 31.163 (Å) with standard deviation 0.023 (Å)
# Average Ly of 6_1_3 is 28.662 (Å) with standard deviation 0.022 (Å)

# %%
# Plotting Lz
plt.plot(g_1_z, label='3_1_3')
plt.plot(g_2_z, label='3_2_3')
plt.plot(g_3_z, label='5_2_2')
plt.plot(g_4_z, label='6_1_6')
plt.plot(g_5_z, label='6_1_3')
plt.legend()
plt.xlabel('Time (fs)')
plt.ylabel('Lz (Å)')
plt.title('Lz vs Time')
plt.show()
# Print average Lz with standard deviation, the float values are not more than three decimal places
print('Average Lz of 3_1_3 is', np.round(np.mean(g_1_z),3),'(Å)', 'with standard deviation', np.round(np.std(g_1_z),3),'(Å)')
print('Average Lz of 3_2_3 is', np.round(np.mean(g_2_z),3),'(Å)', 'with standard deviation', np.round(np.std(g_2_z),3),'(Å)')
print('Average Lz of 5_2_2 is', np.round(np.mean(g_3_z),3),'(Å)', 'with standard deviation', np.round(np.std(g_3_z),3),'(Å)')
print('Average Lz of 6_1_6 is', np.round(np.mean(g_4_z),3),'(Å)', 'with standard deviation', np.round(np.std(g_4_z),3),'(Å)')
print('Average Lz of 6_1_3 is', np.round(np.mean(g_5_z),3),'(Å)', 'with standard deviation', np.round(np.std(g_5_z),3),'(Å)')
# Out:
# Average Lz of 3_1_3 is 26.066 (Å) with standard deviation 0.023 (Å)
# Average Lz of 3_2_3 is 28.128 (Å) with standard deviation 0.023 (Å)
# Average Lz of 5_2_2 is 29.143 (Å) with standard deviation 0.023 (Å)
# Average Lz of 6_1_6 is 31.163 (Å) with standard deviation 0.023 (Å)
# Average Lz of 6_1_3 is 28.662 (Å) with standard deviation 0.022 (Å)

# %%
# Plotting PotEng
plt.plot(g_1_pe, label='3_1_3')
plt.plot(g_2_pe, label='3_2_3')
plt.plot(g_3_pe, label='5_2_2')
plt.plot(g_4_pe, label='6_1_6')
plt.plot(g_5_pe, label='6_1_3')
plt.legend()
plt.xlabel('Time (fs)')
plt.ylabel('PotEng (eV)')
plt.title('PotEng vs Time')
plt.show()
# Print average PotEng with standard deviation, the float values are not more than three decimal places
print('Average PotEng of 3_1_3 is', np.round(np.mean(g_1_pe),3),'(eV)', 'with standard deviation', np.round(np.std(g_1_pe),3),'(eV)')
print('Average PotEng of 3_2_3 is', np.round(np.mean(g_2_pe),3),'(eV)', 'with standard deviation', np.round(np.std(g_2_pe),3),'(eV)')
print('Average PotEng of 5_2_2 is', np.round(np.mean(g_3_pe),3),'(eV)', 'with standard deviation', np.round(np.std(g_3_pe),3),'(eV)')
print('Average PotEng of 6_1_6 is', np.round(np.mean(g_4_pe),3),'(eV)', 'with standard deviation', np.round(np.std(g_4_pe),3),'(eV)')
print('Average PotEng of 6_1_3 is', np.round(np.mean(g_5_pe),3),'(eV)', 'with standard deviation', np.round(np.std(g_5_pe),3),'(eV)')
# Out:
# Average PotEng of 3_1_3 is -19188.89 (eV) with standard deviation 1.082 (eV)
# Average PotEng of 3_2_3 is -27691.321 (eV) with standard deviation 1.362 (eV)
# Average PotEng of 5_2_2 is -26254.874 (eV) with standard deviation 1.503 (eV)
# Average PotEng of 6_1_6 is -27305.429 (eV) with standard deviation 1.695 (eV)
# Average PotEng of 6_1_3 is -21018.857 (eV) with standard deviation 1.326 (eV)

# %%
# Plotting PotEng/atom vs Time in eV/atom
plt.plot(g_1_pe/1350, label='3_1_3')
plt.plot(g_2_pe/1701, label='3_2_3')
plt.plot(g_3_pe/1890, label='5_2_2')
plt.plot(g_4_pe/2214, label='6_1_6')
plt.plot(g_5_pe/1836, label='6_1_3')
plt.legend()
plt.xlabel('Time (fs)')
plt.ylabel('PotEng/atom (eV/atom)')
plt.title('PotEng/atom vs Time')
plt.show()
# Print average PotEng/atom with standard deviation, the float values are not more than three decimal places
print('Average PotEng/atom of 3_1_3 is', np.round(np.mean(g_1_pe/1000),3),'(eV/atom)', 'with standard deviation', np.round(np.std(g_1_pe/1000),3),'(eV/atom)')
print('Average PotEng/atom of 3_2_3 is', np.round(np.mean(g_2_pe/1000),3),'(eV/atom)', 'with standard deviation', np.round(np.std(g_2_pe/1000),3),'(eV/atom)')
print('Average PotEng/atom of 5_2_2 is', np.round(np.mean(g_3_pe/1000),3),'(eV/atom)', 'with standard deviation', np.round(np.std(g_3_pe/1000),3),'(eV/atom)')
print('Average PotEng/atom of 6_1_6 is', np.round(np.mean(g_4_pe/1000),3),'(eV/atom)', 'with standard deviation', np.round(np.std(g_4_pe/1000),3),'(eV/atom)')
print('Average PotEng/atom of 6_1_3 is', np.round(np.mean(g_5_pe/1000),3),'(eV/atom)', 'with standard deviation', np.round(np.std(g_5_pe/1000),3),'(eV/atom)')
# Out:
# Average PotEng/atom of 3_1_3 is -19.189 (eV/atom) with standard deviation 0.001 (eV/atom)
# Average PotEng/atom of 3_2_3 is -27.691 (eV/atom) with standard deviation 0.001 (eV/atom)
# Average PotEng/atom of 5_2_2 is -26.255 (eV/atom) with standard deviation 0.002 (eV/atom)
# Average PotEng/atom of 6_1_6 is -27.305 (eV/atom) with standard deviation 0.002 (eV/atom)
# Average PotEng/atom of 6_1_3 is -21.019 (eV/atom) with standard deviation 0.001 (eV/atom)

# %%
# Plotting TotEng
plt.plot(g_1_tot, label='3_1_3')
plt.plot(g_2_tot, label='3_2_3')
plt.plot(g_3_tot, label='5_2_2')
plt.plot(g_4_tot, label='6_1_6')
plt.plot(g_5_tot, label='6_1_3')
plt.legend()
plt.xlabel('Time (fs)')
plt.ylabel('TotEng (eV)')
plt.title('TotEng vs Time')
plt.show()
# Print average TotEng with standard deviation, the float values are not more than three decimal places
print('Average TotEng of 3_1_3 is', np.round(np.mean(g_1_tot),3),'(eV)', 'with standard deviation', np.round(np.std(g_1_tot),3),'(eV)')
print('Average TotEng of 3_2_3 is', np.round(np.mean(g_2_tot),3),'(eV)', 'with standard deviation', np.round(np.std(g_2_tot),3),'(eV)')
print('Average TotEng of 5_2_2 is', np.round(np.mean(g_3_tot),3),'(eV)', 'with standard deviation', np.round(np.std(g_3_tot),3),'(eV)')
print('Average TotEng of 6_1_6 is', np.round(np.mean(g_4_tot),3),'(eV)', 'with standard deviation', np.round(np.std(g_4_tot),3),'(eV)')
print('Average TotEng of 6_1_3 is', np.round(np.mean(g_5_tot),3),'(eV)', 'with standard deviation', np.round(np.std(g_5_tot),3),'(eV)')
# Plotting all the properties togethe
# Out:
# Average TotEng of 3_1_3 is -19136.4 (eV) with standard deviation 1.571 (eV)
# Average TotEng of 3_2_3 is -27625.409 (eV) with standard deviation 1.726 (eV)
# Average TotEng of 5_2_2 is -26181.537 (eV) with standard deviation 1.915 (eV)
# Average TotEng of 6_1_6 is -27219.602 (eV) with standard deviation 2.215 (eV)
# Average TotEng of 6_1_3 is -20947.823 (eV) with standard deviation 1.978 (eV)

# %%
# plot TotEng/atom vs Time in eV/atom   
plt.plot(g_1_tot/1350, label='3_1_3')
plt.plot(g_2_tot/1701, label='3_2_3')
plt.plot(g_3_tot/1890, label='5_2_2')
plt.plot(g_4_tot/2214, label='6_1_6')
plt.plot(g_5_tot/1836, label='6_1_3')
plt.legend()
plt.xlabel('Time (fs)')
plt.ylabel('TotEng/atom (eV/atom)')
plt.title('TotEng/atom vs Time')
plt.show()
# Print average TotEng/atom with standard deviation, the float values are not more than three decimal places
print('Average TotEng/atom of 3_1_3 is', np.round(np.mean(g_1_tot/1000),3),'(eV/atom)', 'with standard deviation', np.round(np.std(g_1_tot/1000),3),'(eV/atom)')
print('Average TotEng/atom of 3_2_3 is', np.round(np.mean(g_2_tot/1000),3),'(eV/atom)', 'with standard deviation', np.round(np.std(g_2_tot/1000),3),'(eV/atom)')
print('Average TotEng/atom of 5_2_2 is', np.round(np.mean(g_3_tot/1000),3),'(eV/atom)', 'with standard deviation', np.round(np.std(g_3_tot/1000),3),'(eV/atom)')
print('Average TotEng/atom of 6_1_6 is', np.round(np.mean(g_4_tot/1000),3),'(eV/atom)', 'with standard deviation', np.round(np.std(g_4_tot/1000),3),'(eV/atom)')
print('Average TotEng/atom of 6_1_3 is', np.round(np.mean(g_5_tot/1000),3),'(eV/atom)', 'with standard deviation', np.round(np.std(g_5_tot/1000),3),'(eV/atom)')
# Out:
# Average TotEng/atom of 3_1_3 is -19.136 (eV/atom) with standard deviation 0.002 (eV/atom)
# Average TotEng/atom of 3_2_3 is -27.625 (eV/atom) with standard deviation 0.002 (eV/atom)
# Average TotEng/atom of 5_2_2 is -26.182 (eV/atom) with standard deviation 0.002 (eV/atom)
# Average TotEng/atom of 6_1_6 is -27.22 (eV/atom) with standard deviation 0.002 (eV/atom)
# Average TotEng/atom of 6_1_3 is -20.948 (eV/atom) with standard deviation 0.002 (eV/atom)

# %%
# Plot all the properties in bar graph with error bars
# Density
x = ['3_1_3', '3_2_3', '5_2_2', '6_1_6', '6_1_3']
y = [np.mean(g_1_d), np.mean(g_2_d), np.mean(g_3_d), np.mean(g_4_d), np.mean(g_5_d)]
yerr = [np.std(g_1_d), np.std(g_2_d), np.std(g_3_d), np.std(g_4_d), np.std(g_5_d)]
plt.bar(x, y, yerr=yerr, align='center', alpha=0.5, ecolor='black', capsize=10)
plt.ylabel('Density (g/cm³)')
plt.title('Density of all glass compositions')
plt.show()

# %%
# volume    
x = ['3_1_3', '3_2_3', '5_2_2', '6_1_6', '6_1_3']
y = [np.mean(g_1_v), np.mean(g_2_v), np.mean(g_3_v), np.mean(g_4_v), np.mean(g_5_v)]
yerr = [np.std(g_1_v), np.std(g_2_v), np.std(g_3_v), np.std(g_4_v), np.std(g_5_v)]
plt.bar(x, y, yerr=yerr, align='center', alpha=0.5, ecolor='black', capsize=10)
plt.ylabel('Volume (Å³)')
plt.title('Volume of all glass compositions')
plt.show()

# %%
# PotEng/atom
x = ['3_1_3', '3_2_3', '5_2_2', '6_1_6', '6_1_3']
y = [np.mean(g_1_pe/1350), np.mean(g_2_pe/1701), np.mean(g_3_pe/1890), np.mean(g_4_pe/2214), np.mean(g_5_pe/1836)]
yerr = [np.std(g_1_pe/1350), np.std(g_2_pe/1701), np.std(g_3_pe/1890), np.std(g_4_pe/2214), np.std(g_5_pe/1836)]
plt.bar(x, y, yerr=yerr, align='center', alpha=0.5, ecolor='black', capsize=10)
plt.ylabel('PotEng/atom (eV/atom)')
plt.title('PotEng/atom of all glass compositions')
plt.show()

# %%
# TotEng/atom
x = ['3_1_3', '3_2_3', '5_2_2', '6_1_6', '6_1_3']
y = [np.mean(g_1_tot/1350), np.mean(g_2_tot/1701), np.mean(g_3_tot/1890), np.mean(g_4_tot/2214), np.mean(g_5_tot/1836)]
yerr = [np.std(g_1_tot/1350), np.std(g_2_tot/1701), np.std(g_3_tot/1890), np.std(g_4_tot/2214), np.std(g_5_tot/1836)]
plt.bar(x, y, yerr=yerr, align='center', alpha=0.5, ecolor='black', capsize=10)
plt.ylabel('TotEng/atom (eV/atom)')
plt.title('TotEng/atom of all glass compositions')
plt.show()

# %%
# get last frame for each of these simulation trajectory for further MD simulations 
# we will use ovito to get the last frame of the trajectory
from fileinput import filename
from ovito.io import *
from ovito.modifiers import *
from ovito.pipeline import *
from ovito.data import *
import numpy as np 
import tidynamics

# %%
#g_3_1_3 = import_file('/nfshome/deshmukh/vaibhav/frank_jÜlich/lmp_3_1_3/large/simu/dump_nvt_prod.out')
#g_3_2_3 = import_file('/nfshome/deshmukh/vaibhav/frank_jÜlich/lmp_3_2_3/large/simu/dump_nvt_prod.out')
#g_5_2_2 = import_file('/nfshome/deshmukh/vaibhav/frank_jÜlich/lmp_5_2_2/large/simu/dump_nvt_prod.out')
#g_6_1_6 = import_file('/nfshome/deshmukh/vaibhav/frank_jÜlich/lmp_6_1_6/large/simu/dump_nvt_prod.out')
g_6_1_3 = import_file('/nfshome/deshmukh/vaibhav/frank_jÜlich/lmp_6_1_3_2/simu_2/dump_nvt_prod.out')

# %%
g_3_1_3.add_to_scene()
def setup_particle_types(frame, data):
        types = data.particles_.particle_types_
        types.type_by_id_(1).name = "O"
        types.type_by_id_(2).name = "Na"
        types.type_by_id_(4).name = "Si"
        types.type_by_id_(5).name = "P"
g_3_1_3.modifiers.append(setup_particle_types)

def modify1(frame: int, data: DataCollection):

        charge_dict = {"Si": 2.4, "Zr": 2.4, "P": 3.0, "O":-1.2, "Na":0.6}     # Padone charges 
        mass_dict = {"Zr": 91.224,
                "Si": 28.086,
                "P": 30.974,
                "O": 15.999,
                "Na": 22.99}
        charge = data.particles_.create_property("Charge", data = np.ones(data.particles.count))
        mass = data.particles_.create_property("Mass", data = np.ones(data.particles.count))
        ptypes = data.particles_.particle_types_
        for i in range(data.particles.count):
            charge[i] = charge_dict[ptypes.type_by_id(ptypes[i]).name]
            mass[i] = mass_dict[ptypes.type_by_id(ptypes[i]).name]
        
g_3_1_3.modifiers.append(modify1)

# %%
data = g_6_1_3.compute(frame = -1)

# %%
export_file(data, '/nfshome/deshmukh/vaibhav/frank_jÜlich/lmp_6_1_3_2/simu_2/last_frame_5_2_2.data', 'lammps/data', atom_style='full')
