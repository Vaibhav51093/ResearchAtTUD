# %%
import lammps_logfile 
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd

# %%
# Bulk 
df_x_bulk = [2.676e-10, 2.8875994564237363e-10, 3.616205395089529e-10, 5.280036866968131e-10, 6.59515246173405e-10, 8.156036626855895e-10]
df_y_bulk = [1.955e-10 , 2.0886703575086082e-10, 2.899924133993208e-10, 3.392186255738555e-10, 4.97409487083185e-10, 6.490755192910298e-10]
df_z_bulk = [3.776e-10, 4.704e-10, 6.503e-10, 1.019e-09, 1.144e-09, 1.721e-09]
df_tot_bulk = [2.802e-10, 3.2267566046441153e-10, 4.3397098430275793e-10, 6.287407707568896e-10, 7.669749110855299e-10, 1.061893060658873e-09]
df_x_bulk_err = [4.987e-11]
df_y_bulk_err = [3.007e-11]
df_z_bulk_err = [4.234e-11]
df_tot_bulk_err = [3.069e-11]

# %%
# IDp02 :- 
ex_v_02 = [-1.192244778907767, -1.2752557227371164, -0.9541429126841736, -1.1354932803688675, -1.0849768295454765, -1.2618590081242282]  
ex_e_02 = [0.938, 0.9374, 0.9375, 0.9368, 0.936, 0.936]
df_x_gb_02 = [2.2476331474722678e-08,5.815441673373161e-08,8.12667665454058e-08,1.0071004060451249e-07,1.5921619429307266e-07,1.9646508933993487e-07]
df_y_gb_02 = [5.103931359179042e-09,1.4360640275591814e-08,2.4503403201956696e-08,4.5187776123806354e-08,5.878016508688874e-08,7.336108067750209e-08]
df_z_gb_02 = [6.44482081058179e-11,1.2190116473955224e-10,2.0516636979823456e-10,2.7227190968040803e-10,3.6150258558910395e-10,4.960109693013598e-10]
#df_tot_gb_02 = [9.214903680669179e-09,2.4212319391354326e-08,3.532511203905358e-08,4.872336287933308e-08,7.278595398851683e-08,9.010739366224612e-08]
df_tot_gb_02 = [[4.632222380585751e-09,1.2150156930266406e-08,1.772261190632998e-08,2.444008280104391e-08,3.6499539988414186e-08,4.518821215357005e-08]]
df_x_overall_02 = [1.518e-10,2.578e-10,4.003e-10,5.685e-10,7.054e-10,1.007e-09]
df_y_overall_02 = [1.650e-10,3.566e-10,4.777e-10,6.313e-10,9.118e-10,1.126e-09]
df_z_overall_02 = [8.090e-11,1.639e-10,2.470e-10,3.593e-10,4.950e-10,6.317e-10]
df_tot_overall_02 = [(df_x_overall_02[0]+df_y_overall_02[0]+df_z_overall_02[0])/3,(df_x_overall_02[1]+df_y_overall_02[1]+df_z_overall_02[1])/3,(df_x_overall_02[2]+df_y_overall_02[2]+df_z_overall_02[2])/3,(df_x_overall_02[3]+df_y_overall_02[3]+df_z_overall_02[3])/3,(df_x_overall_02[4]+df_y_overall_02[4]+df_z_overall_02[4])/3,(df_x_overall_02[5]+df_y_overall_02[5]+df_z_overall_02[5])/3]

# %%
#IDp03:- 
ex_v_03 = [-0.69448139084542, -0.9646916863336152, -0.5890251260391381, -1.085607681504318, -0.954533079464779, -1.0356609470884122]  
ex_e_03 = [3.199651403278875, 3.0519389767349576, 3.046837762366901, 2.966528157381867, 3.0556163857513967, 2.989894884287723]
df_x_overall_08_big = [1.212e-10,2.070e-10,3.199e-10,4.742e-10,5.926e-10,8.139e-10]
df_y_overall_08_big = [5.637e-11,1.136e-10,1.838e-10,3.034e-10,3.770e-10,5.175e-10]
df_z_overall_08_big = [6.869e-11,8.197e-11,1.095e-10,1.194e-10,1.525e-10,1.525e-10]
df_tot_overall_08_big = [(df_x_overall_08_big[0]+df_y_overall_08_big[0]+df_z_overall_08_big[0])/3,(df_x_overall_08_big[1]+df_y_overall_08_big[1]+df_z_overall_08_big[1])/3,(df_x_overall_08_big[2]+df_y_overall_08_big[2]+df_z_overall_08_big[2])/3,(df_x_overall_08_big[3]+df_y_overall_08_big[3]+df_z_overall_08_big[3])/3,(df_x_overall_08_big[4]+df_y_overall_08_big[4]+df_z_overall_08_big[4])/3,(df_x_overall_08_big[5]+df_y_overall_08_big[5]+df_z_overall_08_big[5])/3]

# %%
# Crystalline 
df_x_cr = [2.676e-10,4.048e-10,5.382e-10,7.035e-10,9.833e-10,1.079e-09]
df_y_cr = [1.955e-10,3.589e-10,4.385e-10,5.782e-10,7.172e-10,9.517e-10]
df_z_cr = [3.776e-10,5.842e-10,7.736e-10,1.009e-09,1.139e-09,1.705e-09]
df_tot_cr = [(df_x_cr[0]+df_y_cr[0]+df_z_cr[0])/3,(df_x_cr[1]+df_y_cr[1]+df_z_cr[1])/3,(df_x_cr[2]+df_y_cr[2]+df_z_cr[2])/3,(df_x_cr[3]+df_y_cr[3]+df_z_cr[3])/3,(df_x_cr[4]+df_y_cr[4]+df_z_cr[4])/3,(df_x_cr[5]+df_y_cr[5]+df_z_cr[5])/3]
df_x_cr_err = [4.987e-11,1.799e-11,8.434e-11,6.659e-11,1.269e-10,1.072e-10]
df_y_cr_err = [3.007e-11,4.855e-11,3.545e-11,1.257e-10,7.993e-11,1.151e-10 ]
df_z_cr_err = [4.234e-11,8.574e-11,1.274e-10,1.633e-10,1.930e-10,1.938e-10]
df_tot_cr_err = [3.069e-11,3.587e-11,4.321e-11,6.826e-11,9.796e-11,5.001e-11]

# %%
# Amorphous
df_x_am = [3.976e-12,6.294e-12,9.300e-12,1.600e-11,2.556e-11,4.328e-11]
df_y_am = [2.866e-12,4.454e-12,7.362e-12,9.834e-12,1.125e-11,1.852e-11]
df_z_am = [3.544e-12,5.660e-12,1.088e-11,1.577e-11,1.908e-11,3.307e-11]
df_tot_am = [(df_x_am[0]+df_y_am[0]+df_z_am[0])/3,(df_x_am[1]+df_y_am[1]+df_z_am[1])/3,(df_x_am[2]+df_y_am[2]+df_z_am[2])/3,(df_x_am[3]+df_y_am[3]+df_z_am[3])/3,(df_x_am[4]+df_y_am[4]+df_z_am[4])/3,(df_x_am[5]+df_y_am[5]+df_z_am[5])/3] 
df_x_am_err = [1.511e-12,1.866e-12,2.274e-12,2.265e-12,9.379e-12,1.905e-11]
df_y_am_err = [1.038e-12,1.101e-12,1.594e-12,1.391e-12,1.515e-12,4.281e-12]
df_z_am_err = [7.618e-13,9.063e-13,1.679e-12,1.089e-12,6.770e-12,6.691e-12]
df_tot_am_err = [9.489e-13,1.078e-12,1.388e-12,1.248e-12,4.866e-12,8.605e-12]

# %%
# Plots, (MSD:- In the suppliments along with PES) 
# 1. Activation energy (Overall), Crystalline, Amorphous, IDp02, IDp03, IDp06, IDp08 (data=I have)
# 2. Activation energy (Individual), Crystalline, Amorphous, IDp02, IDp03, IDp06, IDp08 (Data=I have)
# 3. Excess energy vs diffusion (I have)
# 4. formation energy vs diffusion (I have)
# 5. Formation energy vs excess volume (I have)
# 6. RDF plot last :- Crystalline vs grain vs gb vs amorphous     (Need to investigate) 
# 7. Cordination number:- Crystalline vs grain vs gb vs amorphous (Need to investigate)

# %%
import scipy.constants as const
import sys  
sys.path.insert(0, '/nfshome/deshmukh/vaibhav/scripts')
import analysis_msd as ms
temp_new = []    
t_1 = []     
temp = [523,573,623,673,723,773]               # 1/K
# Bulk 
Ea, c, _ = ms.msd.fit_arrhenius(temp, df_tot_bulk)                      # Activation energy 
arr = (c * np.exp(-Ea / (const.k / const.e * np.array(temp))))*0.0001   # get log of diffusion

# Bulk 
Ea_1, c_1, _ = ms.msd.fit_arrhenius(temp, df_tot_am)                      # Activation energy 
arr_1 = (c_1 * np.exp(-Ea_1 / (const.k / const.e * np.array(temp))))*0.0001   # get log of diffusion

# IDp02
Ea_2, c_2, _ = ms.msd.fit_arrhenius(temp, df_tot_overall_02)                      # Activation energy 
arr_2 = (c_2 * np.exp(-Ea_2 / (const.k / const.e * np.array(temp))))*0.0001       # get log of diffusion

# IDp03
Ea_3, c_3, _ = ms.msd.fit_arrhenius(temp, df_tot_overall_03)                      # Activation energy 
arr_3 = (c_3 * np.exp(-Ea_3 / (const.k / const.e * np.array(temp))))*0.0001       # get log of diffusion

# IDp06
Ea_4, c_4, _ = ms.msd.fit_arrhenius(temp, df_tot_overall_06)                      # Activation energy 
arr_4 = (c_4 * np.exp(-Ea_4 / (const.k / const.e * np.array(temp))))*0.0001       # get log of diffusion

# IDp08
Ea_5, c_5, _ = ms.msd.fit_arrhenius(temp, df_tot_overall_08_small)                      # Activation energy 
arr_5 = (c_5 * np.exp(-Ea_5 / (const.k / const.e * np.array(temp))))*0.0001       # get log of diffusion

# IDp08
Ea_6, c_6, _ = ms.msd.fit_arrhenius(temp, df_tot_overall_08_big)                      # Activation energy 
arr_6 = (c_6 * np.exp(-Ea_6 / (const.k / const.e * np.array(temp))))*0.0001       # get log of diffusion

# Amorphous
Ea_7, c_7, _ = ms.msd.fit_arrhenius(temp, df_tot_am)                      # Activation energy 
arr_7 = (c_7 * np.exp(-Ea_7 / (const.k / const.e * np.array(temp))))*0.0001       # get log of diffusion

#diff_2 = []   # m2/sec
#for i in arr: 
#    diff_2.append(i/10000)
        
std_arr = []
for i in arr:
    std_arr.append(np.std(i))

std_arr_1 = []
for i in arr_1:
    std_arr_1.append(np.std(i))

std_arr_2 = []
for i in arr_2:
    std_arr_2.append(np.std(i))

std_arr_3 = []
for i in arr_3:
    std_arr_3.append(np.std(i))

std_arr_4 = []
for i in arr_4:
    std_arr_4.append(np.std(i))

std_arr_5 = []
for i in arr_5:
    std_arr_5.append(np.std(i))

std_arr_6 = []
for i in arr_6:
    std_arr_6.append(np.std(i))

std_arr_7 = []
for i in arr_7:
    std_arr_7.append(np.std(i))

t_1 = 1000 / np.array(temp)           # temperature
plusminus = u"\u00B1"
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
plt.rcParams["figure.facecolor"] = "w"
plt.rcParams["figure.figsize"] = (7,7)
plt.rcParams.update({'font.size': 12})
plt.rcParams["axes.linewidth"] = 2
plt.rcParams["patch.linewidth"] = 2
plt.tick_params(bottom=True, top=True, left=True, right=True)
plt.tick_params(axis="y",direction="in",which='both', width=2)
plt.tick_params(axis="x",direction="in",which='both', width=2)
plt.errorbar(t_1,arr,yerr=std_arr,linestyle='--',fmt = 'o',color = 'blue', ecolor = 'blue',label='$E_{Bulk}$ = %.2f eV'%(Ea),capthick=16)
#plt.errorbar(t_1,arr_1,yerr=std_arr_1,linestyle='--',fmt = 'o',color = 'red', ecolor = 'red', elinewidth = 2, capsize=5,label='$E_{amorph}$ = %.2f eV'%(Ea_1))
plt.errorbar(t_1,arr_2,yerr=std_arr_2,linestyle='--',fmt = 'p',color = 'green', ecolor = 'green',label='$E_{Twist_{regular}}$ = %.2f eV'%(Ea_2),capthick=16)
plt.errorbar(t_1,arr_3,yerr=std_arr_3,linestyle='--',fmt = 'v',color = 'orange', ecolor = 'orange', label='$E_{Tilt_{auto}}$ = %.2f eV'%(Ea_3),capthick=16)
plt.errorbar(t_1,arr_4,yerr=std_arr_4,linestyle='--',fmt = '^',color = 'cyan', ecolor = 'cyan', label='$E_{Tilt_{manual}}$ = %.2f eV'%(Ea_4),capthick=16)
plt.errorbar(t_1,arr_5,yerr=std_arr_5,linestyle='--',fmt = '<',color = 'purple', ecolor = 'purple',label='$E_{Twist_{small}}$ = %.2f eV'%(Ea_5),capthick=16)
plt.errorbar(t_1,arr_6,yerr=std_arr_6,linestyle='--',fmt = '>',color = 'brown', ecolor = 'brown', label='$E_{Twist_{big}}$ = %.2f eV'%(Ea_6),capthick=16)
plt.errorbar(t_1,arr_7,yerr=std_arr_7,linestyle='--',fmt = 's',color = 'red', ecolor = 'red', label='$E_{Amorphous}$ = %.2f eV'%(Ea_7),capthick=16)
#plt.plot(t_1, np.exp(result.slope * np.asarray(t_1) + result.intercept), '--', color = color)
plt.ylim([10e-13, 10e-9])
plt.yscale("log")
#plt.title("Arrhenius Plot Crystal vs Amorphous (Ordered)")
plt.xlabel("1000/$Temperature \ [1/K]$", fontsize=16)
plt.ylabel("$D_{Tr}\ [m^2/Sec]$", fontsize=16)
plt.legend(fancybox=False, framealpha=1, shadow=False, borderpad=0.5, frameon=True, edgecolor="black", loc='upper right',fontsize=11,ncol=2)#, bbox_to_anchor=(1.60, 1.019))
plt.savefig('total_conductivity_all.png', bbox_inches='tight', dpi=600, transparent=False)
#plt.legend(ncol=2)
plt.show()

# %%
import scipy.constants as const
import sys  
sys.path.insert(0, '/nfshome/deshmukh/vaibhav/scripts')
import analysis_msd as ms
temp_new = []    
t_1 = []     
temp = [523,573,623,673,723,773]               # 1/K
# Bulk 
Ea, c, _ = ms.msd.fit_arrhenius(temp, df_tot_bulk)                      # Activation energy 
arr = (c * np.exp(-Ea / (const.k / const.e * np.array(temp))))*0.0001   # get log of diffusion

# Bulk 
Ea_1, c_1, _ = ms.msd.fit_arrhenius(temp, df_tot_am)                      # Activation energy 
arr_1 = (c_1 * np.exp(-Ea_1 / (const.k / const.e * np.array(temp))))*0.0001   # get log of diffusion

# IDp02
Ea_2, c_2, _ = ms.msd.fit_arrhenius(temp, df_tot_gb_02)                      # Activation energy 
arr_2 = (c_2 * np.exp(-Ea_2 / (const.k / const.e * np.array(temp))))*0.0001       # get log of diffusion

# IDp03
Ea_3, c_3, _ = ms.msd.fit_arrhenius(temp, df_tot_gb_03)                      # Activation energy 
arr_3 = (c_3 * np.exp(-Ea_3 / (const.k / const.e * np.array(temp))))*0.0001       # get log of diffusion

# IDp06
Ea_4, c_4, _ = ms.msd.fit_arrhenius(temp, df_tot_gb_06)                      # Activation energy 
arr_4 = (c_4 * np.exp(-Ea_4 / (const.k / const.e * np.array(temp))))*0.0001       # get log of diffusion

# IDp08
Ea_5, c_5, _ = ms.msd.fit_arrhenius(temp, df_tot_gb_08_small)                      # Activation energy 
arr_5 = (c_5 * np.exp(-Ea_5 / (const.k / const.e * np.array(temp))))*0.0001       # get log of diffusion

# IDp08
Ea_6, c_6, _ = ms.msd.fit_arrhenius(temp, df_tot_gb_08_big)                      # Activation energy 
arr_6 = (c_6 * np.exp(-Ea_6 / (const.k / const.e * np.array(temp))))*0.0001       # get log of diffusion

#diff_2 = []   # m2/sec
#for i in arr: 
#    diff_2.append(i/10000)
        
std_arr = []
for i in arr:
    std_arr.append(np.std(i))

std_arr_1 = []
for i in arr_1:
    std_arr_1.append(np.std(i))

std_arr_2 = []
for i in arr_2:
    std_arr_2.append(np.std(i))

std_arr_3 = []
for i in arr_3:
    std_arr_3.append(np.std(i))

std_arr_4 = []
for i in arr_4:
    std_arr_4.append(np.std(i))

std_arr_5 = []
for i in arr_5:
    std_arr_5.append(np.std(i))

std_arr_6 = []
for i in arr_6:
    std_arr_6.append(np.std(i))

t_1 = 1000 / np.array(temp)           # temperature
plusminus = u"\u00B1"
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
plt.rcParams["figure.facecolor"] = "w"
plt.rcParams["figure.figsize"] = (7,7)
plt.rcParams.update({'font.size': 12})
plt.rcParams["axes.linewidth"] = 2
plt.rcParams["patch.linewidth"] = 2
#plt.ylim(10e-14, 10e-7)
plt.tick_params(bottom=True, top=True, left=True, right=True)
plt.tick_params(axis="y",direction="in",which='both', width=2)
plt.tick_params(axis="x",direction="in",which='both', width=2)
#plt.errorbar(t_1,arr,yerr=std_arr,linestyle='--',fmt = 'o',color = 'blue', ecolor = 'blue',label='$E_{Bulk}$ = %.2f eV'%(Ea),capthick=16)
#plt.errorbar(t_1,arr_1,yerr=std_arr_1,linestyle='--',fmt = 'o',color = 'red', ecolor = 'red', elinewidth = 2, capsize=5,label='$E_{amorph}$ = %.2f eV'%(Ea_1))
plt.errorbar(t_1,arr_2,yerr=std_arr_2,linestyle='--',fmt = 'p',color = 'green', ecolor = 'green',label='$E_{Twist_{regular}}$ = %.2f eV'%(Ea_2),capthick=16)
plt.errorbar(t_1,arr_3,yerr=std_arr_3,linestyle='--',fmt = 'v',color = 'orange', ecolor = 'orange',label='$E_{Tilt_{auto}}$ = %.2f eV'%(Ea_3),capthick=16)
plt.errorbar(t_1,arr_4,yerr=std_arr_4,linestyle='--',fmt = '^',color = 'cyan', ecolor = 'cyan',label='$E_{Tilt_{manual}}$ = %.2f eV'%(Ea_4),capthick=16)
plt.errorbar(t_1,arr_5,yerr=std_arr_5,linestyle='--',fmt = '<',color = 'purple', ecolor = 'purple',label='$E_{Twist_{small}}$ = %.2f eV'%(Ea_5),capthick=16)
plt.errorbar(t_1,arr_6,yerr=std_arr_6,linestyle='--',fmt = '>',color = 'brown', ecolor = 'brown',label='$E_{Twist_{big}}$ = %.2f eV'%(Ea_6),capthick=16)
#plt.errorbar(t_1,arr_1,yerr=std_arr_1,linestyle='--',fmt = 's',color = 'red', ecolor = 'red',label='$E_{amorph}$ = %.2f eV'%(Ea_1),capthick=16)
#plt.plot(t_1, np.exp(result.slope * np.asarray(t_1) + result.intercept), '--', color = color)
#plt.ylim([10e-13, 10e-6])
plt.yscale("log")
#plt.title("Arrhenius Plot Crystal vs Amorphous (Ordered)")
plt.xlabel("1000/$Temperature \ [1/K]$", fontsize=16)
plt.ylabel("$D_{Tr}\ [m^2/Sec]$", fontsize=16)
plt.legend(fancybox=False, framealpha=1, shadow=False, borderpad=0.5, frameon=True, edgecolor="black", loc='upper right',fontsize=11)#, ncol=2)#, bbox_to_anchor=(1.60, 1.019))
plt.savefig('total_conductivity_all_gb.png', bbox_inches='tight', dpi=600, transparent=False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /nfshome/deshmukh/vaibhav/schulze_project/gb/activation_energy_all.ipynb Cell 12 in <cell line: 17>()
#      <a href='vscode-notebook-cell:/nfshome/deshmukh/vaibhav/schulze_project/gb/activation_energy_all.ipynb#X14sZmlsZQ%3D%3D?line=13'>14</a> arr_1 = (c_1 * np.exp(-Ea_1 / (const.k / const.e * np.array(temp))))*0.0001   # get log of diffusion
#      <a href='vscode-notebook-cell:/nfshome/deshmukh/vaibhav/schulze_project/gb/activation_energy_all.ipynb#X14sZmlsZQ%3D%3D?line=15'>16</a> # IDp02
# ---> <a href='vscode-notebook-cell:/nfshome/deshmukh/vaibhav/schulze_project/gb/activation_energy_all.ipynb#X14sZmlsZQ%3D%3D?line=16'>17</a> Ea_2, c_2, _ = ms.msd.fit_arrhenius(temp, df_tot_gb_02)                      # Activation energy
# ...

# %%
import scipy.constants as const
import sys  
sys.path.insert(0, '/nfshome/deshmukh/vaibhav/scripts')
import analysis_msd as ms
temp_new = []    
t_1 = []     
temp = [523,573,623,673,723,773]               # 1/K
# Bulk 
Ea, c, _ = ms.msd.fit_arrhenius(temp, df_x_bulk)                      # Activation energy 
arr = (c * np.exp(-Ea / (const.k / const.e * np.array(temp))))*0.0001   # get log of diffusion

# Bulk 
Ea_1, c_1, _ = ms.msd.fit_arrhenius(temp, df_x_bulk)                      # Activation energy 
arr_1 = (c_1 * np.exp(-Ea_1 / (const.k / const.e * np.array(temp))))*0.0001   # get log of diffusion

# IDp02
Ea_2, c_2, _ = ms.msd.fit_arrhenius(temp, df_x_gb_02)                      # Activation energy 
arr_2 = (c_2 * np.exp(-Ea_2 / (const.k / const.e * np.array(temp))))*0.0001       # get log of diffusion

# IDp03
Ea_3, c_3, _ = ms.msd.fit_arrhenius(temp, df_x_gb_03)                      # Activation energy 
arr_3 = (c_3 * np.exp(-Ea_3 / (const.k / const.e * np.array(temp))))*0.0001       # get log of diffusion

# IDp06
Ea_4, c_4, _ = ms.msd.fit_arrhenius(temp, df_x_gb_06)                      # Activation energy 
arr_4 = (c_4 * np.exp(-Ea_4 / (const.k / const.e * np.array(temp))))*0.0001       # get log of diffusion

# IDp08
Ea_5, c_5, _ = ms.msd.fit_arrhenius(temp, df_x_gb_08_small)                      # Activation energy 
arr_5 = (c_5 * np.exp(-Ea_5 / (const.k / const.e * np.array(temp))))*0.0001       # get log of diffusion

# IDp08
Ea_6, c_6, _ = ms.msd.fit_arrhenius(temp, df_x_gb_08_big)                      # Activation energy 
arr_6 = (c_6 * np.exp(-Ea_6 / (const.k / const.e * np.array(temp))))*0.0001       # get log of diffusion

#diff_2 = []   # m2/sec
#for i in arr: 
#    diff_2.append(i/10000)
        
std_arr = []
for i in arr:
    std_arr.append(np.std(i))

std_arr_1 = []
for i in arr_1:
    std_arr_1.append(np.std(i))

std_arr_2 = []
for i in arr_2:
    std_arr_2.append(np.std(i))

std_arr_3 = []
for i in arr_3:
    std_arr_3.append(np.std(i))

std_arr_4 = []
for i in arr_4:
    std_arr_4.append(np.std(i))

std_arr_5 = []
for i in arr_5:
    std_arr_5.append(np.std(i))

std_arr_6 = []
for i in arr_6:
    std_arr_6.append(np.std(i))

t_1 = 1000 / np.array(temp)           # temperature
plusminus = u"\u00B1"
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
plt.rcParams["figure.facecolor"] = "w"
plt.rcParams["figure.figsize"] = (7,7)
plt.rcParams.update({'font.size': 12})
plt.rcParams["axes.linewidth"] = 2
plt.rcParams["patch.linewidth"] = 2
plt.tick_params(bottom=True, top=True, left=True, right=True)
plt.tick_params(axis="y",direction="in",which='both', width=2)
plt.tick_params(axis="x",direction="in",which='both', width=2)
plt.errorbar(t_1,arr,yerr=std_arr,linestyle='--',fmt = 'o',color = 'blue', ecolor = 'blue', elinewidth = 2, capsize=5,label='$E_{Bulk}$ = %.2f eV'%(Ea))
#plt.errorbar(t_1,arr_1,yerr=std_arr_1,linestyle='--',fmt = 'o',color = 'red', ecolor = 'red', elinewidth = 2, capsize=5,label='$E_{amorph}$ = %.2f eV'%(Ea_1))
plt.errorbar(t_1,arr_2,yerr=std_arr_2,linestyle='--',fmt = 'o',color = 'green', ecolor = 'green', elinewidth = 2, capsize=5,label='$E_{Twist_{regular}}$ = %.2f eV'%(Ea_2))
plt.errorbar(t_1,arr_3,yerr=std_arr_3,linestyle='--',fmt = 'o',color = 'orange', ecolor = 'orange', elinewidth = 2, capsize=5,label='$E_{Tilt_{auto}}$ = %.2f eV'%(Ea_3))
plt.errorbar(t_1,arr_4,yerr=std_arr_4,linestyle='--',fmt = 'o',color = 'cyan', ecolor = 'cyan', elinewidth = 2, capsize=5,label='$E_{Tilt_{manual}}$ = %.2f eV'%(Ea_4))
plt.errorbar(t_1,arr_5,yerr=std_arr_5,linestyle='--',fmt = 'o',color = 'purple', ecolor = 'purple', elinewidth = 2, capsize=5,label='$E_{Twist_{small}}$ = %.2f eV'%(Ea_5))
plt.errorbar(t_1,arr_6,yerr=std_arr_6,linestyle='--',fmt = 'o',color = 'brown', ecolor = 'brown', elinewidth = 2, capsize=5,label='$E_{Twist_{big}}$ = %.2f eV'%(Ea_6))
#plt.plot(t_1, np.exp(result.slope * np.asarray(t_1) + result.intercept), '--', color = color)
plt.yscale("log")
#plt.title("Arrhenius Plot Crystal vs Amorphous (Ordered)")
plt.xlabel("1000/$Temperature \ [1/K]$", fontsize=16)
plt.ylabel("$D_{Tracer}\ [m^2/Sec]$", fontsize=16)
plt.legend(fancybox=False, framealpha=1, shadow=False, borderpad=1, frameon=True, edgecolor="black", loc='lower left',fontsize=12)#, bbox_to_anchor=(1.60, 1.019))
plt.savefig('total_conductivity_all_gb_x.png', bbox_inches='tight', dpi=600, transparent=False)
plt.show()

# %%
import scipy.constants as const
import sys  
sys.path.insert(0, '/nfshome/deshmukh/vaibhav/scripts')
import analysis_msd as ms
temp_new = []    
t_1 = []     
temp = [523,573,623,673,723,773]               # 1/K
# Bulk 
Ea, c, _ = ms.msd.fit_arrhenius(temp, df_y_bulk)                      # Activation energy 
arr = (c * np.exp(-Ea / (const.k / const.e * np.array(temp))))*0.0001   # get log of diffusion

# Bulk 
Ea_1, c_1, _ = ms.msd.fit_arrhenius(temp, df_y_bulk)                      # Activation energy 
arr_1 = (c_1 * np.exp(-Ea_1 / (const.k / const.e * np.array(temp))))*0.0001   # get log of diffusion

# IDp02
Ea_2, c_2, _ = ms.msd.fit_arrhenius(temp, df_y_gb_02)                      # Activation energy 
arr_2 = (c_2 * np.exp(-Ea_2 / (const.k / const.e * np.array(temp))))*0.0001       # get log of diffusion

# IDp03
Ea_3, c_3, _ = ms.msd.fit_arrhenius(temp, df_y_gb_03)                      # Activation energy 
arr_3 = (c_3 * np.exp(-Ea_3 / (const.k / const.e * np.array(temp))))*0.0001       # get log of diffusion

# IDp06
Ea_4, c_4, _ = ms.msd.fit_arrhenius(temp, df_y_gb_06)                      # Activation energy 
arr_4 = (c_4 * np.exp(-Ea_4 / (const.k / const.e * np.array(temp))))*0.0001       # get log of diffusion

# IDp08
Ea_5, c_5, _ = ms.msd.fit_arrhenius(temp, df_y_gb_08_small)                      # Activation energy 
arr_5 = (c_5 * np.exp(-Ea_5 / (const.k / const.e * np.array(temp))))*0.0001       # get log of diffusion

# IDp08
Ea_6, c_6, _ = ms.msd.fit_arrhenius(temp, df_y_gb_08_big)                      # Activation energy 
arr_6 = (c_6 * np.exp(-Ea_6 / (const.k / const.e * np.array(temp))))*0.0001       # get log of diffusion

#diff_2 = []   # m2/sec
#for i in arr: 
#    diff_2.append(i/10000)
        
std_arr = []
for i in arr:
    std_arr.append(np.std(i))

std_arr_1 = []
for i in arr_1:
    std_arr_1.append(np.std(i))

std_arr_2 = []
for i in arr_2:
    std_arr_2.append(np.std(i))

std_arr_3 = []
for i in arr_3:
    std_arr_3.append(np.std(i))

std_arr_4 = []
for i in arr_4:
    std_arr_4.append(np.std(i))

std_arr_5 = []
for i in arr_5:
    std_arr_5.append(np.std(i))

std_arr_6 = []
for i in arr_6:
    std_arr_6.append(np.std(i))

t_1 = 1000 / np.array(temp)           # temperature
plusminus = u"\u00B1"
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
plt.rcParams["figure.facecolor"] = "w"
plt.rcParams["figure.figsize"] = (7,7)
plt.rcParams.update({'font.size': 12})
plt.rcParams["axes.linewidth"] = 2
plt.rcParams["patch.linewidth"] = 2
plt.tick_params(bottom=True, top=True, left=True, right=True)
plt.tick_params(axis="y",direction="in",which='both', width=2)
plt.tick_params(axis="x",direction="in",which='both', width=2)
plt.errorbar(t_1,arr,yerr=std_arr,linestyle='--',fmt = 'o',color = 'blue', ecolor = 'blue', elinewidth = 2, capsize=5,label='$E_{Bulk}$ = %.2f eV'%(Ea))
#plt.errorbar(t_1,arr_1,yerr=std_arr_1,linestyle='--',fmt = 'o',color = 'red', ecolor = 'red', elinewidth = 2, capsize=5,label='$E_{amorph}$ = %.2f eV'%(Ea_1))
plt.errorbar(t_1,arr_2,yerr=std_arr_2,linestyle='--',fmt = 'o',color = 'green', ecolor = 'green', elinewidth = 2, capsize=5,label='$E_{Twist_{regular}}$ = %.2f eV'%(Ea_2))
plt.errorbar(t_1,arr_3,yerr=std_arr_3,linestyle='--',fmt = 'o',color = 'orange', ecolor = 'orange', elinewidth = 2, capsize=5,label='$E_{Tilt_{auto}}$ = %.2f eV'%(Ea_3))
plt.errorbar(t_1,arr_4,yerr=std_arr_4,linestyle='--',fmt = 'o',color = 'cyan', ecolor = 'cyan', elinewidth = 2, capsize=5,label='$E_{Tilt_{manual}}$ = %.2f eV'%(Ea_4))
plt.errorbar(t_1,arr_5,yerr=std_arr_5,linestyle='--',fmt = 'o',color = 'purple', ecolor = 'purple', elinewidth = 2, capsize=5,label='$E_{Twist_{small}}$ = %.2f eV'%(Ea_5))
plt.errorbar(t_1,arr_6,yerr=std_arr_6,linestyle='--',fmt = 'o',color = 'brown', ecolor = 'brown', elinewidth = 2, capsize=5,label='$E_{Twist_{big}}$ = %.2f eV'%(Ea_6))
#plt.plot(t_1, np.exp(result.slope * np.asarray(t_1) + result.intercept), '--', color = color)
plt.yscale("log")
#plt.title("Arrhenius Plot Crystal vs Amorphous (Ordered)")
plt.xlabel("1000/$Temperature \ [1/K]$", fontsize=16)
plt.ylabel("$D_{Tracer}\ [m^2/Sec]$", fontsize=16)
plt.legend(fancybox=False, framealpha=1, shadow=False, borderpad=1, frameon=True, edgecolor="black", loc='lower left',fontsize=12)#, bbox_to_anchor=(1.60, 1.019))
plt.savefig('total_conductivity_all_gb_y.png', bbox_inches='tight', dpi=600, transparent=False)
plt.show()

# %%
import scipy.constants as const
import sys  
sys.path.insert(0, '/nfshome/deshmukh/vaibhav/scripts')
import analysis_msd as ms
temp_new = []    
t_1 = []     
temp = [523,573,623,673,723,773]               # 1/K
# Bulk 
Ea, c, _ = ms.msd.fit_arrhenius(temp, df_z_bulk)                      # Activation energy 
arr = (c * np.exp(-Ea / (const.k / const.e * np.array(temp))))*0.0001   # get log of diffusion

# Bulk 
Ea_1, c_1, _ = ms.msd.fit_arrhenius(temp, df_z_bulk)                      # Activation energy 
arr_1 = (c_1 * np.exp(-Ea_1 / (const.k / const.e * np.array(temp))))*0.0001   # get log of diffusion

# IDp02
Ea_2, c_2, _ = ms.msd.fit_arrhenius(temp, df_z_gb_02)                      # Activation energy 
arr_2 = (c_2 * np.exp(-Ea_2 / (const.k / const.e * np.array(temp))))*0.0001       # get log of diffusion

# IDp03
Ea_3, c_3, _ = ms.msd.fit_arrhenius(temp, df_z_gb_03)                      # Activation energy 
arr_3 = (c_3 * np.exp(-Ea_3 / (const.k / const.e * np.array(temp))))*0.0001       # get log of diffusion

# IDp06
Ea_4, c_4, _ = ms.msd.fit_arrhenius(temp, df_z_gb_06)                      # Activation energy 
arr_4 = (c_4 * np.exp(-Ea_4 / (const.k / const.e * np.array(temp))))*0.0001       # get log of diffusion

# IDp08
Ea_5, c_5, _ = ms.msd.fit_arrhenius(temp, df_z_gb_08_small)                      # Activation energy 
arr_5 = (c_5 * np.exp(-Ea_5 / (const.k / const.e * np.array(temp))))*0.0001       # get log of diffusion

# IDp08
Ea_6, c_6, _ = ms.msd.fit_arrhenius(temp, df_z_gb_08_big)                      # Activation energy 
arr_6 = (c_6 * np.exp(-Ea_6 / (const.k / const.e * np.array(temp))))*0.0001       # get log of diffusion

#diff_2 = []   # m2/sec
#for i in arr: 
#    diff_2.append(i/10000)
        
std_arr = []
for i in arr:
    std_arr.append(np.std(i))

std_arr_1 = []
for i in arr_1:
    std_arr_1.append(np.std(i))

std_arr_2 = []
for i in arr_2:
    std_arr_2.append(np.std(i))

std_arr_3 = []
for i in arr_3:
    std_arr_3.append(np.std(i))

std_arr_4 = []
for i in arr_4:
    std_arr_4.append(np.std(i))

std_arr_5 = []
for i in arr_5:
    std_arr_5.append(np.std(i))

std_arr_6 = []
for i in arr_6:
    std_arr_6.append(np.std(i))

t_1 = 1000 / np.array(temp)           # temperature
plusminus = u"\u00B1"
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
plt.rcParams["figure.facecolor"] = "w"
plt.rcParams["figure.figsize"] = (7,7)
plt.rcParams.update({'font.size': 12})
plt.rcParams["axes.linewidth"] = 2
plt.rcParams["patch.linewidth"] = 2
plt.tick_params(bottom=True, top=True, left=True, right=True)
plt.tick_params(axis="y",direction="in",which='both', width=2)
plt.tick_params(axis="x",direction="in",which='both', width=2)
plt.errorbar(t_1,arr,yerr=std_arr,linestyle='--',fmt = 'o',color = 'blue', ecolor = 'blue', elinewidth = 2, capsize=5,label='$E_{Bulk}$ = %.2f eV'%(Ea))
#plt.errorbar(t_1,arr_1,yerr=std_arr_1,linestyle='--',fmt = 'o',color = 'red', ecolor = 'red', elinewidth = 2, capsize=5,label='$E_{amorph}$ = %.2f eV'%(Ea_1))
plt.errorbar(t_1,arr_2,yerr=std_arr_2,linestyle='--',fmt = 'o',color = 'green', ecolor = 'green', elinewidth = 2, capsize=5,label='$E_{Twist_{regular}}$ = %.2f eV'%(Ea_2))
plt.errorbar(t_1,arr_3,yerr=std_arr_3,linestyle='--',fmt = 'o',color = 'orange', ecolor = 'orange', elinewidth = 2, capsize=5,label='$E_{Tilt_{auto}}$ = %.2f eV'%(Ea_3))
plt.errorbar(t_1,arr_4,yerr=std_arr_4,linestyle='--',fmt = 'o',color = 'cyan', ecolor = 'cyan', elinewidth = 2, capsize=5,label='$E_{Tilt_{manual}}$ = %.2f eV'%(Ea_4))
plt.errorbar(t_1,arr_5,yerr=std_arr_5,linestyle='--',fmt = 'o',color = 'purple', ecolor = 'purple', elinewidth = 2, capsize=5,label='$E_{Twist_{small}}$ = %.2f eV'%(Ea_5))
plt.errorbar(t_1,arr_6,yerr=std_arr_6,linestyle='--',fmt = 'o',color = 'brown', ecolor = 'brown', elinewidth = 2, capsize=5,label='$E_{Twist_{big}}$ = %.2f eV'%(Ea_6))
#plt.plot(t_1, np.exp(result.slope * np.asarray(t_1) + result.intercept), '--', color = color)
plt.yscale("log")
#plt.title("Arrhenius Plot Crystal vs Amorphous (Ordered)")
plt.xlabel("1000/$Temperature \ [1/K]$", fontsize=16)
plt.ylabel("$D_{Tracer}\ [m^2/Sec]$", fontsize=16)
plt.legend(fancybox=False, framealpha=1, shadow=False, borderpad=1, frameon=True, edgecolor="black", loc='lower left',fontsize=12)#, bbox_to_anchor=(1.60, 1.019))
plt.savefig('total_conductivity_all_gb_z.png', bbox_inches='tight', dpi=600, transparent=False)
plt.show()

# %%
# Amorphous 
import scipy.constants as const
import sys  
sys.path.insert(0, '/nfshome/deshmukh/vaibhav/scripts')
import analysis_msd as ms
temp_new = []    
t_1 = []     
temp = [523,573,623,673,723,773]               # 1/K
# Bulk 
Ea, c, _ = ms.msd.fit_arrhenius(temp, df_x_am)                      # Activation energy 
arr = (c * np.exp(-Ea / (const.k / const.e * np.array(temp))))*0.0001   # get log of diffusion

# Bulk 
Ea_1, c_1, _ = ms.msd.fit_arrhenius(temp, df_y_am)                      # Activation energy 
arr_1 = (c_1 * np.exp(-Ea_1 / (const.k / const.e * np.array(temp))))*0.0001   # get log of diffusion

# IDp02
Ea_2, c_2, _ = ms.msd.fit_arrhenius(temp, df_z_am)                      # Activation energy 
arr_2 = (c_2 * np.exp(-Ea_2 / (const.k / const.e * np.array(temp))))*0.0001       # get log of diffusion

# IDp03
Ea_3, c_3, _ = ms.msd.fit_arrhenius(temp, df_tot_am)                      # Activation energy 
arr_3 = (c_3 * np.exp(-Ea_3 / (const.k / const.e * np.array(temp))))*0.0001       # get log of diffusion

# IDp06
Ea_4, c_4, _ = ms.msd.fit_arrhenius(temp, df_z_gb_06)                      # Activation energy 
arr_4 = (c_4 * np.exp(-Ea_4 / (const.k / const.e * np.array(temp))))*0.0001       # get log of diffusion

# IDp08
Ea_5, c_5, _ = ms.msd.fit_arrhenius(temp, df_z_gb_08_small)                      # Activation energy 
arr_5 = (c_5 * np.exp(-Ea_5 / (const.k / const.e * np.array(temp))))*0.0001       # get log of diffusion

# IDp08
Ea_6, c_6, _ = ms.msd.fit_arrhenius(temp, df_z_gb_08_big)                      # Activation energy 
arr_6 = (c_6 * np.exp(-Ea_6 / (const.k / const.e * np.array(temp))))*0.0001       # get log of diffusion

#diff_2 = []   # m2/sec
#for i in arr: 
#    diff_2.append(i/10000)
        
std_arr = []
for i in arr:
    std_arr.append(np.std(i))

std_arr_1 = []
for i in arr_1:
    std_arr_1.append(np.std(i))

std_arr_2 = []
for i in arr_2:
    std_arr_2.append(np.std(i))

std_arr_3 = []
for i in arr_3:
    std_arr_3.append(np.std(i))

std_arr_4 = []
for i in arr_4:
    std_arr_4.append(np.std(i))

std_arr_5 = []
for i in arr_5:
    std_arr_5.append(np.std(i))

std_arr_6 = []
for i in arr_6:
    std_arr_6.append(np.std(i))

t_1 = 1000 / np.array(temp)           # temperature
plusminus = u"\u00B1"
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
plt.rcParams["figure.facecolor"] = "w"
plt.rcParams["figure.figsize"] = (7,7)
plt.rcParams.update({'font.size': 12})
plt.rcParams["axes.linewidth"] = 2
plt.rcParams["patch.linewidth"] = 2
plt.tick_params(bottom=True, top=True, left=True, right=True)
plt.tick_params(axis="y",direction="in",which='both', width=2)
plt.tick_params(axis="x",direction="in",which='both', width=2)
plt.errorbar(t_1,arr,yerr=std_arr,linestyle='--',fmt = 'o',color = 'blue', ecolor = 'blue', elinewidth = 2, capsize=5,label='$E_{Bulk}$ = %.2f eV'%(Ea))
plt.errorbar(t_1,arr_1,yerr=std_arr_1,linestyle='--',fmt = 'o',color = 'red', ecolor = 'red', elinewidth = 2, capsize=5,label='$E_{amorph}$ = %.2f eV'%(Ea_1))
plt.errorbar(t_1,arr_2,yerr=std_arr_2,linestyle='--',fmt = 'o',color = 'green', ecolor = 'green', elinewidth = 2, capsize=5,label='$E_{Twist_{regular}}$ = %.2f eV'%(Ea_2))
plt.errorbar(t_1,arr_3,yerr=std_arr_3,linestyle='--',fmt = 'o',color = 'orange', ecolor = 'orange', elinewidth = 2, capsize=5,label='$E_{Tilt_{auto}}$ = %.2f eV'%(Ea_3))
#plt.errorbar(t_1,arr_4,yerr=std_arr_4,linestyle='--',fmt = 'o',color = 'cyan', ecolor = 'cyan', elinewidth = 2, capsize=5,label='$E_{Tilt_{manual}}$ = %.2f eV'%(Ea_4))
#plt.errorbar(t_1,arr_5,yerr=std_arr_5,linestyle='--',fmt = 'o',color = 'purple', ecolor = 'purple', elinewidth = 2, capsize=5,label='$E_{Twist_{small}}$ = %.2f eV'%(Ea_5))
#plt.errorbar(t_1,arr_6,yerr=std_arr_6,linestyle='--',fmt = 'o',color = 'brown', ecolor = 'brown', elinewidth = 2, capsize=5,label='$E_{Twist_{big}}$ = %.2f eV'%(Ea_6))
#plt.plot(t_1, np.exp(result.slope * np.asarray(t_1) + result.intercept), '--', color = color)
plt.yscale("log")
#plt.title("Arrhenius Plot Crystal vs Amorphous (Ordered)")
plt.xlabel("1000/$Temperature \ [1/K]$", fontsize=16)
plt.ylabel("$D_{Tracer}\ [m^2/Sec]$", fontsize=16)
plt.legend(fancybox=False, framealpha=1, shadow=False, borderpad=1, frameon=True, edgecolor="black", loc='lower left',fontsize=12)#, bbox_to_anchor=(1.60, 1.019))
#plt.savefig('total_conductivity_all_gb_z.png', bbox_inches='tight', dpi=600, transparent=False)
plt.show()

# %%
labels = ['Bulk','Twist_{regular}','Tilt_{auto}','Tilt_{manual}','Twist_{small}','Twist_{large}']

# %%
x_act = [0.22,0.34,0.29,0.24,0.21,0.25,0.24]
y_act = [0.22,0.25,0.37,0.18,0.23,0.26,0.25]
z_act = [0.22,0.28,0.28,0.22,0.26,0.10,0.11]
tot_act = [0.22,0.31,0.31,0.21,0.24,0.23,0.23]

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# set width of bar
barWidth = 0.25
fig = plt.subplots(figsize =(7, 6))

plt.rcParams["axes.linewidth"] = 2
plt.rcParams["patch.linewidth"] = 2
plt.tick_params(axis="y",direction="in",which='both', width=2)
plt.tick_params(axis="x",direction="in",which='both', width=2)
# set height of bar
IT = x_act
ECE = y_act
CSE = z_act
 
# Set position of bar on X axis
br1 = np.arange(len(IT))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
#br4 = [x + barWidth for x in br3]
 
# Make the plot
plt.bar(br1, IT, color ='r', width = barWidth,edgecolor ='r', label ='$E^x_a$')
plt.bar(br2, ECE, color ='g', width = barWidth,edgecolor ='g', label ='$E^y_a$')
plt.bar(br3, CSE, color ='b', width = barWidth,edgecolor ='b', label ='$E^z_a$')
#plt.bar(br2, tot_act, color ='c', width = barWidth,edgecolor ='c', label ='$D_{tot}$')

# Adding Xticks
plt.xlabel(' ', fontweight ='bold', fontsize = 15)
plt.ylabel('$Activation$ $Energy$ $[eV]$', fontsize = 16)
plt.xticks([r + barWidth for r in range(len(IT))],
        ['$Bulk$', '$Amorphous$', '$Twist_{regular}$', '$Tilt_{auto}$', '$Tilt_{manual}$', '$Twist_{small}$', '$Twist_{large}$'],rotation=45)
 
plt.legend(fancybox=False, framealpha=1, shadow=False, borderpad=1, frameon=True, edgecolor="black", loc='upper right',fontsize=12)
plt.savefig('total_cond_all_gb.png', bbox_inches='tight', dpi=600, transparent=False)
plt.show()

# %%
x_act = [0.20,0.29,0.23]
y_act = [0.20,0.37,0.26]
z_act = [0.20,0.28,0.21]
tot_act = [0.20,0.31,0.24]

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# set width of bar
barWidth = 0.25
fig = plt.subplots(figsize =(7, 6))

plt.rcParams["axes.linewidth"] = 2
plt.rcParams["patch.linewidth"] = 2
plt.tick_params(axis="y",direction="in",which='both', width=2)
plt.tick_params(axis="x",direction="in",which='both', width=2)
# set height of bar
IT = x_act
ECE = y_act
CSE = z_act
 
# Set position of bar on X axis
br1 = np.arange(len(IT))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
#br4 = [x + barWidth for x in br3]
 
# Make the plot
plt.bar(br1, IT, color ='r', width = barWidth,edgecolor ='r', label ='$E^x_a$')
plt.bar(br2, ECE, color ='g', width = barWidth,edgecolor ='g', label ='$E^y_a$')
plt.bar(br3, CSE, color ='b', width = barWidth,edgecolor ='b', label ='$E^z_a$')
#plt.bar(br2, tot_act, color ='c', width = barWidth,edgecolor ='c', label ='$D_{tot}$')

# Adding Xticks
plt.xlabel(' ', fontweight ='bold', fontsize = 15)
plt.ylabel('$Activation$ $Energy$ $[eV]$', fontsize = 16)
plt.xticks([r + barWidth for r in range(len(IT))],
        ['$Bulk$', '$A$', '$B$'],rotation=45)
 
plt.legend(fancybox=False, framealpha=1, shadow=False, borderpad=1, frameon=True, edgecolor="black", loc='upper right',fontsize=12)
plt.savefig('total_cond_all_gb_report.png', bbox_inches='tight', dpi=600, transparent=False)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# set width of bar
barWidth = 0.25
fig = plt.subplots(figsize =(7, 6))

plt.rcParams["axes.linewidth"] = 2
plt.rcParams["patch.linewidth"] = 2
plt.tick_params(axis="y",direction="in",which='both', width=2)
plt.tick_params(axis="x",direction="in",which='both', width=2)
# set height of bar
IT = tot_act
#ECE = y_act
#CSE = z_act
 
# Set position of bar on X axis
br1 = np.arange(len(IT))
br2 = [x + barWidth for x in br1]
#br3 = [x + barWidth for x in br2]
 
# Make the plot
#plt.bar(br1, IT, color ='r', width = barWidth,
#        edgecolor ='r', label ='$D_tot$')
plt.bar(br2, IT, color ='brown', width = 0.5,
        edgecolor ='brown', label ='$E^{tot}_a$')
#plt.bar(br3, CSE, color ='b', width = barWidth,
#        edgecolor ='b', label ='$D_z$')
 
# Adding Xticks
plt.xlabel(' ', fontweight ='bold', fontsize = 15)
plt.ylabel('$Activation$ $Energy$ $[eV]$', fontsize = 16)
plt.xticks([r + barWidth for r in range(len(IT))],
        ['$Bulk$', '$Amorphous$', '$Twist_{regular}$', '$Tilt_{auto}$', '$Tilt_{manual}$', '$Twist_{small}$', '$Twist_{large}$'],rotation=45)
 
plt.legend(fancybox=False, framealpha=1, shadow=False, borderpad=1, frameon=True, edgecolor="black", loc='upper right',fontsize=12)
plt.savefig('total_cond_all_gb_2.png', bbox_inches='tight', dpi=600, transparent=False)
plt.show()
